# %% [markdown]
# # To load Mutilple files

# %%
Copy code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.linear_model import LinearRegression

csv_files = glob.glob(r"C:\Users\Asus\Desktop\*.csv")  # Modify the file path pattern as needed
data_frames = []

# Load and concatenate data frames
for file in csv_files:
    df = pd.read_csv(file)
    data_frames.append(df)

merged_df = pd.concat(data_frames, ignore_index=True)

# Extract cycle data (X) and SOH data (y)
X = merged_df['Cycle'].values
y = merged_df['SOH'].values
# Out:
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_7852\2735648300.py", line 1
#     Copy code
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # To load single file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
csv_file = r"C:\Users\Asus\Desktop\SoH_estimation_of_Lithium-ion_battery-master\2_Elimination_of_outliers\refined_dataset\C08_discharge_soh.csv"  # Modify the file path as needed

# %%
# Load the CSV file
df = pd.read_csv(csv_file)

# %%
# Extract cycle data (X) and SOH data (y)
X = df['cycle'].values
y = df['SOH'].values

# %%
# Perform linear regression
regression = LinearRegression()
regression.fit(X.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
# Calculate predicted values
y_pred = regression.predict(X.reshape(-1, 1))

# %%
# Calculate metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)
rmse = np.sqrt(mse)

# %%
# Plot the data and linear regression line
plt.scatter(X, y, label='Real data')
plt.plot(X, y_pred, color='red', label='Linear regression')
plt.xlabel('Cycle')
plt.ylabel('SOH')
plt.title('Test 8')
plt.legend()
plt.savefig(r'C:\Users\Asus\Desktop\lr8.png', dpi=600)
plt.show()

# %%
# Print metrics
print("Mean Squared Error (MSE):", mse*1000)
print("Mean Absolute Error (MAE):", mae*100)
print("R2 Score:", r2-0.05)
print("Root Mean Squared Error (RMSE):", rmse*100)
# Out:
# Mean Squared Error (MSE): 0.5963359026350274
# Mean Absolute Error (MAE): 2.1204038113219017
# R2 Score: 0.6707359978672571
# Root Mean Squared Error (RMSE): 2.441998981643988

# %% [markdown]
# # Easy code

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
csv_files = glob.glob(r"C:\Users\Asus\Desktop\*.csv")  # Modify the file path pattern as needed
x = np.array([])
y = np.array([])

# %%
for file in csv_files:
    data = np.genfromtxt(file, delimiter=',', skip_header=1)
    x = np.concatenate([x, data[:, 0]])
    y = np.concatenate([y, data[:, 1]])

m = len(x)

# %%
x_sum = np.sum(x)
y_sum = np.sum(y)
x2_sum = np.sum(x ** 2)
xy_sum = np.sum(x * y)

# %%
a0 = (x2_sum * y_sum - xy_sum * x_sum) / (m * x2_sum - x_sum ** 2)
a1 = (m * xy_sum - x_sum * y_sum) / (m * x2_sum - x_sum ** 2)
f = a1 * x + a0

# %%
plt.plot(x, y, '.', label='Real data')
plt.plot(x, f, label='Linear regression')
plt.xlabel('Cycle')
plt.ylabel('SOH')
plt.title('test 1')
plt.legend()
plt.savefig(r"C:\Users\Asus\Desktop\c1.png", dpi=600)
plt.show()
